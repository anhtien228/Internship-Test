# %% [markdown]
# ### Section 2. Find missed element of a set
#
# ### **Description**
#
# Assuming we have an array that is a permutation of an array A. We randomly drop one element of the given array. Implement a function that take the droped array and output is the missed element.

# %% [markdown]
# ### **Implementation**

# %%
# Import libraries
import numpy as np

# %% [markdown]
# **Approach explanation**
#
# The input array is the permutation of a sequential list. So if would be more tricky for us find out the missed value. <br>
#
# For the algorithm, if we check again the context and requirement of this problem, we will find the difference between array A and its permutation. Since all values are unique, the sum of elements in array A is larger than the sum of elements in A's permutation by an amount equal to the dropped element.
#
# For example:
#
# A = [3, 4, 2, 1, 6], B (permutation of A) = [4, 2, 6, 1]
#
# Sum of A = 3+4+2+1+6 = 16 ($S_A$)
#
# Sum of B = 4+2+6+1 = 13 ($S_B$)
#
# Substraction ($S_A$) - ($S_B$) = 3, and it is the value we need to find
#
# This problem is very tricky in the first glance to me as I try to implement it using such redundant algorithm or mechanism like sorting, hash-table. But in the end, those thoughts may results in the complexity of time and code.

# %%
def missed_elem(arr, N):
  """
  Parameters
  ---------
  arr: a form of ndarray represent the array of unique elements range from (1, N-1)
  Type: ndarray

  N: number of elements in the input array
  Type: int

  Ouput
  -----
  elem: the element that is missed out from the array
  Type: int

  """
  elem = 0 # Stores the missed value

  sum_perm = np.sum(arr) # Sum of array derived from A
  sum_A = N*(N+1)/2 # Basic sum of N natural number

  elem = int(sum_A - sum_perm)
  
  return elem

# %% [markdown]
# **Small test**

# %%
test_1 = np.array([5, 1, 4, 2, 3])
n = 6
print("The given array: {} \nThe missed element: {}".format(test_1, missed_elem(test_1,n)))
# Out:
# The given array: [5 1 4 2 3]
# The missed element: 6

# %% [markdown]
# **Batch test**

# %%
import random
from itertools import permutations

# %%
### Create test cases

for i in range(50):
  # Generate new array within the constraints from assignment and get random permutation
  N = random.randint(2, 20) # 10**6 is quite big for me to check
  rng = np.random.default_rng()
  array_perm = rng.permutation(np.arange(1,N+1))

  # Drop randomly one element
  N_drop = random.randint(0, N-1)
  array_perm = np.delete(array_perm, N_drop)

  # Run the function
  print("Test case {}\nThe given array: {} \nThe missed element: {}\n-------------".format(i+1, list(array_perm), missed_elem(array_perm,N)))
# Out:
# Test case 1
# The given array: [19, 11, 16, 5, 1, 7, 8, 6, 17, 4, 13, 3, 15, 14, 12, 10, 2, 9]
# The missed element: 18
# -------------
# Test case 2
# The given array: [3, 4, 1, 5, 7, 9, 10, 6, 2, 8]
# The missed element: 11
# -------------
# Test case 3
# The given array: [1, 3, 4]
# The missed element: 2
# -------------
# Test case 4
# The given array: [1, 3]
# The missed element: 2
# -------------
# Test case 5
# The given array: [6, 5, 7, 12, 2, 4, 8, 9, 14, 13, 11, 1, 10]
# The missed element: 3
# -------------
# Test case 6
# The given array: [3, 4, 2, 5, 1, 7]
# The missed element: 6
# -------------
# Test case 7
# The given array: [1, 7, 3, 2, 4, 9, 10, 8, 6, 12, 14, 11, 5]
# The missed element: 13
# -------------
# Test case 8
# The given array: [2]
# The missed element: 1
# -------------
# Test case 9
# The given array: [4, 2, 1, 5]
# The missed element: 3
# -------------
# Test case 10
# The given array: [2, 9, 7, 14, 11, 3, 18, 12, 17, 15, 8, 16, 6, 1, 4, 5, 10]
# The missed element: 13
# -------------
# Test case 11
# The given array: [6, 4, 1, 3, 12, 5, 8, 9, 11, 13, 2, 10]
# The missed element: 7
# -------------
# Test case 12
# The given array: [3, 1, 2]
# The missed element: 4
# -------------
# Test case 13
# The given array: [1, 7, 10, 12, 8, 3, 9, 5, 6, 11, 2]
# The missed element: 4
# -------------
# Test case 14
# The given array: [8, 10, 9, 2, 3, 12, 7, 1, 13, 14, 11, 6, 5]
# The missed element: 4
# -------------
# Test case 15
# The given array: [1, 14, 11, 17, 13, 2, 5, 4, 8, 6, 16, 15, 9, 12, 7, 10]
# The missed element: 3
# -------------
# Test case 16
# The given array: [14, 9, 7, 10, 17, 13, 8, 5, 3, 4, 11, 15, 16, 12, 1, 2]
# The missed element: 6
# -------------
# Test case 17
# The given array: [3, 8, 9, 5, 1, 7, 6, 2]
# The missed element: 4
# -------------
# Test case 18
# The given array: [2, 6, 4, 7, 3, 13, 14, 11, 8, 5, 12, 1, 10]
# The missed element: 9
# -------------
# Test case 19
# The given array: [2, 12, 4, 6, 7, 1, 8, 11, 3, 10, 13, 9]
# The missed element: 5
# -------------
# Test case 20
# The given array: [2, 3, 6, 4, 1, 7, 5]
# The missed element: 8
# -------------
# Test case 21
# The given array: [2, 20, 1, 4, 3, 13, 9, 10, 19, 16, 17, 18, 6, 8, 11, 12, 5, 7, 14]
# The missed element: 15
# -------------
# Test case 22
# The given array: [4, 6, 5, 1, 8, 9, 2, 3]
# The missed element: 7
# -------------
# Test case 23
# The given array: [10, 2, 13, 12, 1, 7, 9, 5, 3, 8, 11, 6, 4]
# The missed element: 14
# -------------
# Test case 24
# The given array: [1, 2]
# The missed element: 3
# -------------
# Test case 25
# The given array: [4, 3, 1, 6, 5]
# The missed element: 2
# -------------
# Test case 26
# The given array: [2, 3, 9, 1, 5, 4, 8, 6]
# The missed element: 7
# -------------
# Test case 27
# The given array: [5, 1, 2, 4]
# The missed element: 3
# -------------
# Test case 28
# The given array: [1]
# The missed element: 2
# -------------
# Test case 29
# The given array: [3, 9, 4, 16, 15, 10, 17, 13, 6, 1, 5, 2, 18, 11, 14, 8, 12]
# The missed element: 7
# -------------
# Test case 30
# The given array: [7, 2, 3, 8, 5, 1, 4]
# The missed element: 6
# -------------
# Test case 31
# The given array: [9, 13, 14, 4, 5, 12, 10, 15, 11, 6, 1, 7, 2, 3]
# The missed element: 8
# -------------
# Test case 32
# The given array: [11, 2, 12, 3, 6, 1, 9, 4, 7, 8, 10, 13]
# The missed element: 5
# -------------
# Test case 33
# The given array: [10, 3, 2, 9, 4, 8, 7, 5, 1]
# The missed element: 6
# -------------
# Test case 34
# The given array: [1, 5, 6, 4, 3, 2]
# The missed element: 7
# -------------
# Test case 35
# The given array: [2, 5, 7, 1, 3, 9, 8, 10, 4]
# The missed element: 6
# -------------
# Test case 36
# The given array: [11, 7, 3, 12, 2, 16, 4, 17, 15, 13, 5, 1, 10, 9, 8, 6]
# The missed element: 14
# -------------
# Test case 37
# The given array: [5, 4, 1, 3, 6, 7]
# The missed element: 2
# -------------
# Test case 38
# The given array: [4, 2, 3, 7, 8, 11, 9, 5, 6, 10]
# The missed element: 1
# -------------
# Test case 39
# The given array: [8, 6, 15, 2, 5, 14, 13, 10, 3, 19, 1, 17, 7, 16, 4, 11, 9, 18]
# The missed element: 12
# -------------
# Test case 40
# The given array: [8, 10, 1, 4, 5, 6, 7, 2, 9, 11]
# The missed element: 3
# -------------
# Test case 41
# The given array: [1, 3, 4]
# The missed element: 2
# -------------
# Test case 42
# The given array: [14, 13, 11, 10, 4, 6, 9, 5, 1, 12, 7, 8, 3, 15]
# The missed element: 2
# -------------
# Test case 43
# The given array: [5, 2, 3, 6, 1, 4]
# The missed element: 7
# -------------
# Test case 44
# The given array: [8, 14, 12, 2, 7, 1, 17, 4, 5, 6, 9, 10, 3, 11, 18, 15, 16]
# The missed element: 13
# -------------
# Test case 45
# The given array: [10, 7, 2, 13, 1, 4, 12, 5, 8, 6, 9, 14, 11]
# The missed element: 3
# -------------
# Test case 46
# The given array: [1, 3]
# The missed element: 2
# -------------
# Test case 47
# The given array: [11, 1, 2, 8, 3, 10, 14, 4, 9, 12, 5, 15, 13, 7]
# The missed element: 6
# -------------
# Test case 48
# The given array: [6, 7, 1, 2, 4, 9, 8, 3]
# The missed element: 5
# -------------
# Test case 49
# The given array: [7, 1, 8, 3, 2, 6, 4]
# The missed element: 5
# -------------
# Test case 50
# The given array: [4, 5, 1, 3, 2]
# The missed element: 6
# -------------
